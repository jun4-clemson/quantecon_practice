# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize']=(10,6)

np.random.seed(19680801)

# compute pie slices
N =20
Θ = np.linspace(0.0,2*np.pi,N,endpoint=False) # linspace split line to N pieces. endpoint =False (20 pieses), endpoint=True (19 pieses)
radii = 10*np.random.rand(N)
width = np.pi / 4 *np.random.rand(N)
colors = plt.cm.viridis(radii / 10.) # why 10.?

ax = plt.subplot(111,projection = 'polar')
ax.bar(Θ,radii,width=width,bottom=0.0,color=colors,alpha=0.5)

plt.show()

# %% [markdown]
# m change code to markdown. y change markdown to code

# %%
# %%file foo.py # %%file can create a new file
# print("foobar")
# Out:
# Writing foo.py
